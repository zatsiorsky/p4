# %%
import pandas as pd

# %%
df = pd.read_csv("grid_results4.csv")

# %%
df.columns
# Out:
# Index([u'eta', u' gamma', u' epsilon', u' mds', u' mys', u' mss', u' mean',
#        u' 50_perc', u' 80_perc', u' max', u' death_mode', u' 30_mean',
#        u' 30_50_perc', u' 30_80_perc', u' 30_max', u' 30_death_mode',
#        u' 30_low_mean', u' 30_low_50_perc', u' 30_low_80_perc', u' 30_low_max',
#        u' 30_low_death_mode', u' 30_high_mean', u' 30_high_50_perc',
#        u' 30_high_80_perc', u' 30_high_max', u' 30_high_death_mode'],
#       dtype='object')

# %%
df.sort_values([" 50_perc", " mean"], ascending=False)
# Out:
#       eta   gamma   epsilon   mds   mys   mss   mean   50_perc   80_perc  \
# 994   0.5     1.0      0.50   100    25     3   5.57       2.0       4.0
# 1085  0.5     1.0      0.01    80    50     1  37.64       1.0       7.6
# 1046  0.5     1.0      0.10    80    35     1  30.02       1.0      38.8
# 988   0.5     1.0      0.50   100    50     3  17.55       1.0      11.4
# 952   0.5     1.0      0.90   100    25     3  14.24       1.0       7.6
# 1078  0.5     1.0      0.01   100    25     3  13.40       1.0      25.2
# 1123  0.5     0.5      0.90   100    15     3  13.25       1.0      10.8
# 388   0.5     1.0      0.90    60    35     2  10.59       1.0      11.6
# 1076  0.5     1.0      0.01   100    25     1  10.53       1.0      10.0
# 948   0.5     1.0      0.90   100    35     2   8.78       1.0       7.2
# 960   0.5     1.0      0.90    80    50     2   7.22       1.0       5.2
# 1047  0.5     1.0      0.10    80    35     2   7.11       1.0       3.4
# ...
